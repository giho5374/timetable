# %%
from tkinter import *
import sqlite3
from tkinter import ttk
from tkinter.messagebox import *


import pandas as pd
Location = 'table1.csv'
df=pd.read_csv(Location)

import numpy as np
f=lambda x:-x


def put(y):
    global RT
    RT = (df.Time==y)
    df.loc[(RT),'Reservation']=df.Reservation.apply(f)
    df.loc[RT,'User']=entered_id
    
    


    
def db_check(entered_id,entered_pw): #DB연동.
    con = sqlite3.connect('student.db')
    cur = con.cursor()
    ID = entered_id
    password = entered_pw

    sql = "SELECT * FROM StudentInfo WHERE ID = %s" %(ID)
    

    try:
        cur.execute(sql)
        data = cur.fetchone()
        if data[2]==password:
            result = 1
        else:
            result = 0
    except :
        result=2
        pass
    return result
    

class multiFrames(Tk):
    def __init__(self, *args, **kwargs):
        Tk.__init__(self, *args, **kwargs)

        container = Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}
        for F in (StartPage, PageTwo,Table1,Table2):
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame
            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame("StartPage")

    def show_frame(self, page_name):
        frame = self.frames[page_name]
        frame.tkraise()
        
def after_unlogin():
    resultwin.destroy()
def PWmsg():
    showinfo("Message", "비밀번호를 확인해주세요.")
def IDmsg():
    showinfo("Message", "아이디를 확인해주세요.")

class StartPage(Frame):
    def __init__(self, parent, controller):
        global s1,s2
        s1 = StringVar()
        s2 = StringVar()
        main_login="Login Plz"
        Frame.__init__(self, parent)
        self.controller = controller
        label=Label(self,font='맑은고딕 20 bold',height=2,text="MJU Reservation System")
        label.config(anchor=S)
        label.pack()
        
        def login_fun():
            global resultwin
            global entered_id
            entered_id=s1.get()
            entered_pw=s2.get()
            result1 = db_check(entered_id, entered_pw)
            if result1==0:
                PWmsg()
            elif result1==2:
                IDmsg()
            else: controller.show_frame("PageTwo")

    
    
        self.buttonframe1=Frame(self)
        self.buttonframe1.pack(fill=X,anchor=N) #anchor 방향, NW,W,E....가능
        self.label=Label(self.buttonframe1,text="ID")
        self.label.pack(side=LEFT,padx=10,pady=10)
        self.button1=Entry(self.buttonframe1,textvariable = s1)
        self.button1.pack(side=LEFT,pady=10)
        self.buttonframe=Frame(self)
        self.buttonframe.pack(fill=X,anchor=N)
        self.label=Label(self.buttonframe,text="PW")
        self.label.pack(side=LEFT,padx=5,pady=10)
        self.solin=Entry(self.buttonframe,textvariable = s2,show='*')
        self.solin.pack(side=LEFT,padx=5)  #x축 여백 pady=y축 여백
        button = Button(self, text="Login",
                           command=login_fun)
        button.pack(anchor=W,padx=38)
        
class PageTwo(Frame):
    def __init__(self, parent, controller):
        Frame.__init__(self, parent)
        self.controller = controller
        self.choiceframe=Frame(self)
        self.choiceframe.pack(fill=X,anchor=N)
        Button(self.choiceframe,text="Home",
               command= lambda : controller.show_frame("StartPage")).pack(anchor=NE)
        label=Label(self.choiceframe,font='맑은고딕 20 bold',text="Choice Your Table")
        label.config(anchor=S)
        label.pack()
        Button(self,text="First Table",
               command= lambda : controller.show_frame("Table1")).pack(anchor=W,pady=20)
        Button(self,text="Second Table",
               command= lambda : controller.show_frame("Table2")).pack(anchor=W)     
        

class Table1(Frame):
      
    def __init__(self, parent, controller):
        
                
        
        Frame.__init__(self, parent)
        self.controller = controller
        Button(self,text="Home",
               command= lambda : controller.show_frame("StartPage")).pack(anchor=NE)
        label=Label(self,font='맑은고딕 20 bold',text="Table1")
        label.config(anchor=S)
        label.pack()
        hour=1
        def show():
            global hour
            hour=st.get()
        st=StringVar()
        st.set(1)
        self.tableframe=Frame(self)
        self.tableframe.pack(fill=Y,anchor=N)
        
        Radiobutton(self.tableframe,text='1hr',command=show,value=1,variable=st).pack(side=LEFT,padx=5)        
        Radiobutton(self.tableframe,text='2hr',command=show,value=2,variable=st).pack(side=LEFT,padx=5)
        Radiobutton(self.tableframe,text='3hr',command=show,value=3,variable=st).pack(side=LEFT,padx=5)
        def event(button,time):
            hour=st.get()
            btn1=button1['text']
            btn2=button2['text']
            btn3=button3['text']
            btn4=button4['text']
            btn5=button5['text']
            btn6=button6['text']
            btn7=button7['text']
            btn8=button8['text']
            btn9=button9['text']
            btn10=button10['text']
            btn11=button11['text']
            btn12=button12['text']
            num_btn=[btn1,btn2,btn3,btn4,btn5,btn6,btn7,btn8,btn9,btn10,btn11,btn12]           
            if num_btn.count("Reservated")!=int(hour):
                if(button['text'] =="Selectable"):
                    put(time)
                    button['text']="Reservated"
                    button['fg'] = 'white'
                    button['bg'] = 'black'   
                else:       
                    button['text'] = 'Selectable'
                    button['fg'] = 'black'
                    button['bg'] = '#EEEEEE'          
            else:       
                button['text'] = 'Selectable'
                button['fg'] = 'black'
                button['bg'] = '#EEEEEE'      
                          
        
        self.time1=Frame(self)
        self.time1.pack(fill=X)
        t1=Button(self.time1,text='09:00~10:00', command = lambda: event(button1,time1))
        t1.pack(side=LEFT)
        time1=t1["text"]
        button1=Button(self.time1,text='Selectable')
        button1.pack(side=LEFT)
        
        
        self.time2=Frame(self)
        self.time2.pack(fill=X)
        t2=Button(self.time2,text='10:00~11:00', command = lambda: event(button2,time2))
        t2.pack(side=LEFT)
        time2=t2["text"]
        button2=Button(self.time2,text='Selectable')
        button2.pack(side=LEFT)
        
        self.time3=Frame(self)
        self.time3.pack(fill=X)
        t3=Button(self.time3,text='11:00~12:00', command = lambda: event(button3,time3))
        t3.pack(side=LEFT)
        time3=t3["text"]
        button3=Button(self.time3,text='Selectable')
        button3.pack(side=LEFT)
        
        self.time4=Frame(self)
        self.time4.pack(fill=X)
        t4=Button(self.time4,text='12:00~13:00', command = lambda: event(button4,time4))
        t4.pack(side=LEFT)
        time4=t4["text"]
        button4=Button(self.time4,text='Selectable')
        button4.pack(side=LEFT)
        
        self.time5=Frame(self)
        self.time5.pack(fill=X)
        t5=Button(self.time5,text='13:00~14:00', command = lambda: event(button5,time5))
        t5.pack(side=LEFT)
        time5=t5["text"]
        button5=Button(self.time5,text='Selectable')
        button5.pack(side=LEFT)
        
        self.time6=Frame(self)
        self.time6.pack(fill=X)
        t6=Button(self.time6,text='14:00~15:00', command = lambda: event(button6,time6))
        t6.pack(side=LEFT)
        time6=t6["text"]
        button6=Button(self.time6,text='Selectable')
        button6.pack(side=LEFT)
        
        self.time7=Frame(self)
        self.time7.pack(fill=X)
        t7=Button(self.time7,text='15:00~16:00', command =  lambda:event(button7,time7))
        t7.pack(side=LEFT)
        time7=t7["text"]
        button7=Button(self.time7,text='Selectable')
        button7.pack(side=LEFT)
        
        self.time8=Frame(self)
        self.time8.pack(fill=X)
        t8=Button(self.time8,text='16:00~17:00', command = lambda: event(button8,time8))
        t8.pack(side=LEFT)
        time8=t8["text"]
        button8=Button(self.time8,text='Selectable')
        button8.pack(side=LEFT)
        
        self.time9=Frame(self)
        self.time9.pack(fill=X)
        t9=Button(self.time9,text='17:00~18:00', command = lambda: event(button9,time9))
        t9.pack(side=LEFT)
        time9=t9["text"]
        button9=Button(self.time9,text='Selectable')
        button9.pack(side=LEFT)
        
        self.time10=Frame(self)
        self.time10.pack(fill=X)
        t10=Button(self.time10,text='18:00~19:00', command = lambda: event(button10,time10))
        t10.pack(side=LEFT)
        time10=t10["text"]
        button10=Button(self.time10,text='Selectable')
        button10.pack(side=LEFT)  
        
        self.time11=Frame(self)
        self.time11.pack(fill=X)
        t11=Button(self.time11,text='19:00~20:00', command = lambda: event(button11,time11))
        t11.pack(side=LEFT)
        time11=t11["text"]
        button11=Button(self.time11,text='Selectable')
        button11.pack(side=LEFT)
        
        self.time12=Frame(self)
        self.time12.pack(fill=X)
        t12=Button(self.time12,text='20:00~21:00', command = lambda: event(button12,time12))
        t12.pack(side=LEFT)
        time12=t12["text"]
        button12=Button(self.time12,text='Selectable')
        button12.pack(side=LEFT)
        
        self.time13=Frame(self)
        self.time13.pack(fill=X)
        t13=Button(self.time13,text='21:00~22:00', command = lambda:event(button13,time13))
        t13.pack(side=LEFT)
        time13=t13["text"]
        button13=Button(self.time13,text='Selectable')
        button13.pack(side=LEFT)
        
       
        btn1=button1['text']
        btn2=button2['text']
        btn3=button3['text']
        btn4=button4['text']
        btn5=button5['text']
        btn6=button6['text']
        btn7=button7['text']
        btn8=button8['text']
        btn9=button9['text']
        btn10=button10['text']
        btn11=button11['text']
        btn12=button12['text']
        num_btn=[btn1,btn2,btn3,btn4,btn5,btn6,btn7,btn8,btn9,btn10,btn11,btn12]
        
        save=Frame(self)
        save.pack(fill=X)
        
        def after_save():
            controller.show_frame("StartPage")
            showinfo("Message", "저장되었습니다.")
            df.to_csv('table1.csv',index=False)
            
        Button(save,text="Save",command=after_save).pack(side=RIGHT)
        
        
        

class Table2(Frame):
    def __init__(self, parent, controller):
        Frame.__init__(self, parent)
        self.controller = controller
        Button(self,text="Home",
               command= lambda : controller.show_frame("StartPage")).pack(anchor=NE)
        label=Label(self,font='맑은고딕 20 bold',text="Table2")
        label.config(anchor=S)
        label.pack()
        hour=1
        def show():
            global hour
            hour=st.get()
        st=StringVar()
        st.set(1)
        self.tableframe=Frame(self)
        self.tableframe.pack(fill=Y,anchor=N)
        
        Radiobutton(self.tableframe,text='1hr',command=show,value=1,variable=st).pack(side=LEFT,padx=5)        
        Radiobutton(self.tableframe,text='2hr',command=show,value=2,variable=st).pack(side=LEFT,padx=5)
        Radiobutton(self.tableframe,text='3hr',command=show,value=3,variable=st).pack(side=LEFT,padx=5)
        def event(button,time):
            hour=st.get()
            btn1=button1['text']
            btn2=button2['text']
            btn3=button3['text']
            btn4=button4['text']
            btn5=button5['text']
            btn6=button6['text']
            btn7=button7['text']
            btn8=button8['text']
            btn9=button9['text']
            btn10=button10['text']
            btn11=button11['text']
            btn12=button12['text']
            num_btn=[btn1,btn2,btn3,btn4,btn5,btn6,btn7,btn8,btn9,btn10,btn11,btn12]           
            if num_btn.count("Reservated")!=int(hour):
                if(button['text'] =="Selectable"):
                    put(time)
                    button['text']="Reservated"
                    button['fg'] = 'white'
                    button['bg'] = 'black'   
                else:       
                    button['text'] = 'Selectable'
                    button['fg'] = 'black'
                    button['bg'] = '#EEEEEE'          
            else:       
                button['text'] = 'Selectable'
                button['fg'] = 'black'
                button['bg'] = '#EEEEEE'      
                          
        
        self.time1=Frame(self)
        self.time1.pack(fill=X)
        t1=Button(self.time1,text='09:00~10:00', command = lambda: event(button1,time1))
        t1.pack(side=LEFT)
        time1=t1["text"]
        button1=Button(self.time1,text='Selectable')
        button1.pack(side=LEFT)
        
        
        self.time2=Frame(self)
        self.time2.pack(fill=X)
        t2=Button(self.time2,text='10:00~11:00', command = lambda: event(button2,time2))
        t2.pack(side=LEFT)
        time2=t2["text"]
        button2=Button(self.time2,text='Selectable')
        button2.pack(side=LEFT)
        
        self.time3=Frame(self)
        self.time3.pack(fill=X)
        t3=Button(self.time3,text='11:00~12:00', command = lambda: event(button3,time3))
        t3.pack(side=LEFT)
        time3=t3["text"]
        button3=Button(self.time3,text='Selectable')
        button3.pack(side=LEFT)
        
        self.time4=Frame(self)
        self.time4.pack(fill=X)
        t4=Button(self.time4,text='12:00~13:00', command = lambda: event(button4,time4))
        t4.pack(side=LEFT)
        time4=t4["text"]
        button4=Button(self.time4,text='Selectable')
        button4.pack(side=LEFT)
        
        self.time5=Frame(self)
        self.time5.pack(fill=X)
        t5=Button(self.time5,text='13:00~14:00', command = lambda: event(button5,time5))
        t5.pack(side=LEFT)
        time5=t5["text"]
        button5=Button(self.time5,text='Selectable')
        button5.pack(side=LEFT)
        
        self.time6=Frame(self)
        self.time6.pack(fill=X)
        t6=Button(self.time6,text='14:00~15:00', command = lambda: event(button6,time6))
        t6.pack(side=LEFT)
        time6=t6["text"]
        button6=Button(self.time6,text='Selectable')
        button6.pack(side=LEFT)
        
        self.time7=Frame(self)
        self.time7.pack(fill=X)
        t7=Button(self.time7,text='15:00~16:00', command =  lambda:event(button7,time7))
        t7.pack(side=LEFT)
        time7=t7["text"]
        button7=Button(self.time7,text='Selectable')
        button7.pack(side=LEFT)
        
        self.time8=Frame(self)
        self.time8.pack(fill=X)
        t8=Button(self.time8,text='16:00~17:00', command = lambda: event(button8,time8))
        t8.pack(side=LEFT)
        time8=t8["text"]
        button8=Button(self.time8,text='Selectable')
        button8.pack(side=LEFT)
        
        self.time9=Frame(self)
        self.time9.pack(fill=X)
        t9=Button(self.time9,text='17:00~18:00', command = lambda: event(button9,time9))
        t9.pack(side=LEFT)
        time9=t9["text"]
        button9=Button(self.time9,text='Selectable')
        button9.pack(side=LEFT)
        
        self.time10=Frame(self)
        self.time10.pack(fill=X)
        t10=Button(self.time10,text='18:00~19:00', command = lambda: event(button10,time10))
        t10.pack(side=LEFT)
        time10=t10["text"]
        button10=Button(self.time10,text='Selectable')
        button10.pack(side=LEFT)  
        
        self.time11=Frame(self)
        self.time11.pack(fill=X)
        t11=Button(self.time11,text='19:00~20:00', command = lambda: event(button11,time11))
        t11.pack(side=LEFT)
        time11=t11["text"]
        button11=Button(self.time11,text='Selectable')
        button11.pack(side=LEFT)
        
        self.time12=Frame(self)
        self.time12.pack(fill=X)
        t12=Button(self.time12,text='20:00~21:00', command = lambda: event(button12,time12))
        t12.pack(side=LEFT)
        time12=t12["text"]
        button12=Button(self.time12,text='Selectable')
        button12.pack(side=LEFT)
        
        self.time13=Frame(self)
        self.time13.pack(fill=X)
        t13=Button(self.time13,text='21:00~22:00', command = lambda:event(button13,time13))
        t13.pack(side=LEFT)
        time13=t13["text"]
        button13=Button(self.time13,text='Selectable')
        button13.pack(side=LEFT)
        
       
        btn1=button1['text']
        btn2=button2['text']
        btn3=button3['text']
        btn4=button4['text']
        btn5=button5['text']
        btn6=button6['text']
        btn7=button7['text']
        btn8=button8['text']
        btn9=button9['text']
        btn10=button10['text']
        btn11=button11['text']
        btn12=button12['text']
        num_btn=[btn1,btn2,btn3,btn4,btn5,btn6,btn7,btn8,btn9,btn10,btn11,btn12]
        
        save=Frame(self)
        save.pack(fill=X)
        
        def after_save():
            controller.show_frame("StartPage")
            showinfo("Message", "저장되었습니다.")
            df.to_csv('table1.csv',index=False)
            
        Button(save,text="Save",command=after_save).pack(side=RIGHT)
        

main = multiFrames()
def donothing():
    filewin = Toplevel(main) # 새로운 창 띄우기
    Button(filewin, text="Do nothing button").pack()

def openFile():
    global fname
    fname = askopenfilename(filetypes = (("CSV" , "*.csv"),("All Files","*.*")))
    messagebox.showinfo('You choosed:', fname)
    loadData()
    
def loadData(): 
    df_csv = pd.read_csv(fname) 
    display(df_csv)
menubar = Menu(main)
filemenu = Menu(menubar, tearoff=0)
menubar.add_cascade(label="File", menu=filemenu)
filemenu.add_command(label="First Page", command=lambda : main.show_frame("StartPage"))
filemenu.add_command(label="Exit", command=lambda : main.destroy())


helpmenu = Menu(menubar)
menubar.add_cascade(label="Help", menu=helpmenu)
helpmenu.add_command(label="About...", command=donothing)

main.config(menu=menubar)
main.title("Table Reservation System")
main.geometry("500x500+200+100")
main.resizable(0,0) #창 크기 조절 0은 불가 1은 가능
main.mainloop()

# %%
def db_check(entered_id,entered_pw): #DB연동.
    con = sqlite3.connect('student.db')
    cur = con.cursor()
    
    ID = entered_id
    password = entered_pw

    sql = "SELECT * FROM StudentInfo WHERE ID = %s" %(ID)
    

    try:
        cur.execute(sql)
        data = cur.fetchone()
        if data[2]==password:
            result = 1
        else:
            result = 0
    except :
        
    return result

# %%
# Out:
# Writing button_reverse_function.py

# %%
import pandas as pd
from pandas import Series, DataFrame
Reservation_df = pd.read_csv('ReservationInfo.csv')

import sqlite3
con2=sqlite3.connect('Reservation.db')
StudentInfo_df.to_sql('ReservationInfo', con2, index=False)

DF_Region02 = pd.read_sql("SELECT * FROM ReservationInfo", con2)
con2.commit()

# %%
from tkinter import*
kkk=Tk()
result='None'
st=StringVar()
st.set(None)
def show():
    result=st.get()
    label.insert(0,result)
Radiobutton(kkk,text='1',value=1,variable=st,command=show).pack()
Radiobutton(kkk,text='2',value=2,variable=st,command=show).pack()
Radiobutton(kkk,text='3',value=3,variable=st,command=show).pack()
label=Entry(kkk).pack()
kkk.mainloop()
